# %% [markdown]
# # Semantic Benchmark C - Dataset Overview
# Reviews prepared dataset paths, label balance, and code-size distributions from the data root.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
while PROJECT_ROOT.name and not (PROJECT_ROOT / "pipelines").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from spectral_code.evaluation.notebook_helpers import (
    bcb_spec,
    xglue_spec,
    semantic_spec,
    display_dataset_overview,
    display_pipeline_validation,
    display_similarity_distribution_report,
    display_tuning_report,
    display_pair_code_and_graphs,
)

# %%
LANGUAGE = "C"
spec = semantic_spec(LANGUAGE)

pair_df = display_dataset_overview(spec)
