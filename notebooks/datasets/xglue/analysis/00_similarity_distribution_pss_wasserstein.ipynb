# %% [markdown]
# # XGLUE - Similarity Distributions
# Reviews XGLUE dataset artifacts, then plots PSS/Wasserstein score distributions and a graph-backed code-pair example.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve()
while PROJECT_ROOT.name and not (PROJECT_ROOT / "pipelines").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from spectral_code.evaluation.notebook_helpers import (
    bcb_spec,
    xglue_spec,
    semantic_spec,
    display_dataset_overview,
    display_pipeline_validation,
    display_similarity_distribution_report,
    display_tuning_report,
    display_pair_code_and_graphs,
)

# %%
spec = xglue_spec()
GRAPH_TYPES = ["ast", "cfg", "ddg", "pdg", "cpg"]
METRICS = ["pss", "wasserstein"]
SAMPLE_SIZE = 1000

pair_df = display_dataset_overview(spec)
score_df = display_similarity_distribution_report(
    spec,
    sample_size=SAMPLE_SIZE,
    graph_types=GRAPH_TYPES,
    metrics=METRICS,
)

display_pair_code_and_graphs(spec, label=1, graph_types=["cpg"])
